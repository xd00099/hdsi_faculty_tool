# %%
import pickle

# %%
all_authors = pickle.load(open('./data/output/all_authors.pickle', 'rb'))

# %%
all_authors['Yusu Wang'].items()
# Out:
# dict_items([(2017, ['study vietoris rip complexes metric wedge sum metric glue vietoris rip complex wedge equip natural metric homotopy equivalent wedge vietoris rip complexes provide generalizations metric space glue common isometric subset main example deduce homotopy type vietoris rip complex metric graph glue sufficiently short path compare lengths certain loop input graph result persistent homology homological dimension vietoris rip complexes wide class metric graph', 'parse diverse nerve cells biological type necessary understand neural circuit organization morphology intuitive criterion neuronal classification proxy connectivity morphological diversity variability preclude resolve granularity discrete cell group population continuum combine genetic label high resolution large volume light microscopy establish platform genetic single neuron anatomy resolve register quantify complete neuron morphologies mouse brain discover cortical axonic cells aacs cardinal gabaergic interneur
# ...
